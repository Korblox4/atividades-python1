# %% [markdown]
# <a href="https://colab.research.google.com/github/Korblox4/atividades-python1/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade 01 — Introdução ao Python

# %%
print("Minha primeira atividade no Google Colab")
print("Aprendendo Python e GitHub")

# %%
print("\n--- Informações da atividade ---")
disciplina = input("disciplina:")
conteudo = input("conteúdo:")
atividade = input("atividade:")
# Out:
# --- Informações da atividade ---
# disciplina:ALP
# conteúdo:Aprendendo phyton
# atividade:Atividade 01
